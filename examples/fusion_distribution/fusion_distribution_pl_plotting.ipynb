# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
times_firm3d = np.load("data/times.npy")
lfa_firm3d = np.load("data/loss_frac_arr.npy")
pitch_invs = np.load("data/pitch_invs.npy")
# poinc_drho_list = np.load("../trapped_map/poinc_drho_list.npy")
# pitch_invs = np.linspace(5.9,6.4,10)

lf_firm3d = lfa_firm3d[:,-1] # take only final timepoint

# %%
obj = np.load('/Users/paullab/codes/DESC_fork_08282025/DESC_TrappedRes/desc/ResonanceOpt/poinc_plot_DESC.npy')
obj_lambda_DESC = np.sum(obj,axis=0)
obj_lambda_DESC = np.sum(obj_lambda_DESC,axis=1)
DESC_rhos = np.linspace(5.95,6.1,15)

fig, ax1 = plt.subplots()

# ax1.set_title(r"$\%$ of Lost Particles at "+str(times_firm3d[0,-1])+"s Compared With Objective Function")

# Left y-axis
ax1.plot(pitch_invs, obj_lambda_DESC, color='tab:blue')
ax1.set_xlabel(r"$B_c~[T]$",fontsize=18)
ax1.set_ylabel(r"$F(B_c)$", color='tab:blue',fontsize=18)
ax1.tick_params(axis='y', labelcolor='tab:blue',labelsize=16)

# Right y-axis
ax2 = ax1.twinx()
ax2.plot(pitch_invs, poinc_drho_list, color='tab:red', linestyle='--')
ax2.set_ylabel(r'FIRM3D Total $\Delta \rho$', color='tab:red',fontsize=18)
ax2.tick_params(axis='y', labelcolor='tab:red',labelsize=16)
ax1.tick_params(axis='x', labelsize=16)

ax1.yaxis.get_offset_text().set_fontsize(16)


# Optional: combined legend
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
# ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='best')
plt.tight_layout()
plt.savefig("drho_vs_pitch.pdf")

# plt.title("DESC vs. Loss Fraction")
# plt.grid(True, which='both', axis='both', linestyle='--', alpha=0.5)
# plt.tight_layout()
# plt.plot(pitch_invs,obj_lambda_DESC,label="DESC")
# plt.plot(pitch_invs, lfa_firm3d[:,-1]*100,label='Loss Fraction [%]') # using last time point to plot loss fraction
# plt.savefig("loss_fraction_vs_pitch_largegrrange.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 11
#       6 fig, ax1 = plt.subplots()
#       8 # ax1.set_title(r"$\%$ of Lost Particles at "+str(times_firm3d[0,-1])+"s Compared With Objective Function")
#       9
#      10 # Left y-axis
# ---> 11 ax1.plot(pitch_invs, obj_lambda_DESC, color='tab:blue')
#      12 ax1.set_xlabel(r"$B_c~[T]$",fontsize=18)
#      13 ax1.set_ylabel(r"$F(B_c)$", color='tab:blue',fontsize=18)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firm3d_fork_10132025/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
fig,ax = plt.subplots()
ax.plot(pitch_invs,lf_firm3d,'*--')
ax.set_xlabel(r"$B_{crit}")
ax.set_ylabel(r"Loss Fraction at t = 0.01s")
# Out:
# Text(0, 0.5, 'Loss Fraction at t = 0.01s')

# %%
# Out:
# (3, 1000)
